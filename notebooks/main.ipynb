# %%
import yaml
import pandas as pd

config = yaml.safe_load(open("../config/config.yaml"))

if config["mode"] == "full":
    path = "../data/raw/raw_full.csv"
else:
    path = "../data/sample/sample_raw.csv"

df = pd.read_csv(path)

print("Mode:", config["mode"])
print("Shape:", df.shape)
